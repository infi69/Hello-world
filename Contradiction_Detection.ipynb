# %% [markdown]
# <a href="https://colab.research.google.com/github/infi69/Hello-world/blob/master/Contradiction_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gensim
import pandas as pd
import nltk

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
df=pd.read_csv('/content/contradiction_dataset.csv',encoding='cp1252',header=None)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
#df.head()

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#nltk.word_tokenize(str(df.iloc[2]).lower())
for i in (nltk.sent_tokenize(df.iloc[6][0])):
  print(nltk.word_tokenize(i))
#print(nltk.sent_tokenize(df.iloc[6][0]))
# Out:
# ['Al-zarqawi', 'was', 'Palestinian', '.']
# ['Al-zarqawi', 'was', 'Jordanian', '.']

# %%
nltk.sent_tokenize(df.iloc[0][0])
# Out:
# ["Tariq Aziz was not considered a member of Saddam's innermost circle.",
#  "Tariq Aziz was in Saddam's inner circle."]

# %%
data=[]
for i in range(df.shape[0]):
  for j in nltk.sent_tokenize(df.iloc[i][0]):
    data.append(nltk.word_tokenize(j))
      #if re.search('[A-Za-z0-9]',k):
       # data.append(k.lower())

# %%
data
# Out:
# [['Tariq',
#   'Aziz',
#   'was',
#   'not',
#   'considered',
#   'a',
#   'member',
#   'of',
#   'Saddam',
#   "'s",
#   'innermost',
#   'circle',
#   '.'],
#  ['Tariq', 'Aziz', 'was', 'in', 'Saddam', "'s", 'inner', 'circle', '.'],
#  ['Tariq',
#   'Aziz',
#   'kept',
#   'outside',
#   'the',
#   'closed',
#   'circle',
#   'of',
#   'Saddam',
#   "'s",
#   'Sunni',
#   'Moslem',
#   'cronies',
#   '.'],
#  ['Tariq', 'Aziz', 'was', 'in', 'Saddam', "'s", 'inner', 'circle', '.'],
#  ['Tariq',
#   'Aziz',
#   'was',
#   'not',
#   'one',
#   'of',
#   'the',
#   'most',
#   'powerful',
#   'figures',
#   'in',
#   'Saddam',
#   "'s",
#   'regime',
#   '.'],
#  ['Tariq', 'Aziz', 'was', 'prominent', 'in', 'the', 'regime', '.'],
#  ['Tariq', 'Aziz', 'retained', 'influence', '.'],
#  ['Aziz', 'had', 'virtually', 'no', 'power', '.'],
#  ['Alexandros', 'Yiotopoulos', 'is', '58', '.'],
#  ['Alexandros', 'Yiotopoulos', 'is', '59', 'years', 'old', '.'],
# ...

# %%
import re
#mod_data=[]
for i in data:
  #print(i)
  #k=len(i)
  #print(k)
  del_elem=[]
  for j in range(len(i)):
    
    
    if  re.search('[A-Za-z0-9]',i[j]):
      
          i[j]=i[j].lower()
          print(i[j])
    else:
        
        del_elem.append(i[j])
        #k=len(i)
        #print("after removal length %d"%k)
        #print("modified list")
        #print(i)
  for k in del_elem:
    i.remove(k)
# Out:
# Streaming output truncated to the last 5000 lines.
# be
# ruled
# out
# evo
# morales
# is
# the
# top
# presidential
# candidate
# in
# bolivia
# evo
# morales
# is
# bolivian
# president
# evo
# morales
# is
# a
# former
# congressman
# evo
# morales
# is
# a
# congressman
# evo
# morales
# is
# the
# new
# bolivian
# president
# evo
# morales
# is
# a
# congressman
# prime
# minister
# ariel
# sharon
# underwent
# five
# hours
# of
# surgery
# sharon
# underwent
# nine
# hours
# of
# surgery
# sharon
# underwent
# nine
# hours
# of
# surgery
# israeli
# prime
# minister
# ariel
# sharon
# underwent
# seven
# hours
# of
# emergency
# surgery
# fema
# would
# cut
# off
# financing
# for
# most
# rooms
# by
# dec.
# 1
# fema
# set
# the
# dec.
# 15
# and
# jan.
# 7
# deadlines
# for
# cutting
# off
# financing
# for
# most
# rooms
# hezbollah
# fired
# a
# rocket
# that
# killed
# eight
# workers
# hezbollah
# killed
# eight
# israeli
# soldiers
# tamilnet
# reported
# that
# a
# ...

# %%
data[51]
# Out:
# ['it',
#  'sudanese',
#  'government',
#  'supports',
#  'a',
#  'u.n.',
#  'peacekeeping',
#  'force',
#  'to',
#  'replace',
#  'the',
#  'overwhelmed',
#  'african',
#  'union',
#  'force',
#  'of',
#  '7,000']

# %%
s='The'
print(s.lower())
# Out:
# the

# %%
model=gensim.models.Word2Vec(data,min_count=1,window=5,size=40)

# %%
model['tariq']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.00735918, -0.00702171,  0.00770514, -0.006124  , -0.01180074,
#        -0.00074599,  0.01128085, -0.01104256, -0.00358662, -0.00671172,
#        -0.00595039, -0.01232542,  0.00617133, -0.00036269,  0.00182213,
#        -0.00419731, -0.00811285,  0.00686204,  0.01268876, -0.00326469,
#        -0.00472138,  0.00969727,  0.01013094,  0.01328544,  0.00557492,
#        -0.01077985,  0.00319118,  0.01271274, -0.0045898 , -0.00913647,
#        -0.0102739 ,  0.00529798,  0.00183541, -0.01066147, -0.00760496,
#         0.0108172 ,  0.00209738, -0.00990048,  0.00087839,  0.00091039],
#       dtype=float32)

# %%
vocab=list(model.wv.vocab)
vocab
# Out:
# ['tariq',
#  'aziz',
#  'was',
#  'not',
#  'considered',
#  'a',
#  'member',
#  'of',
#  'saddam',
#  "'s",
#  'innermost',
#  'circle',
#  'in',
#  'inner',
#  'kept',
#  'outside',
#  'the',
#  'closed',
#  'sunni',
#  'moslem',
#  'cronies',
#  'one',
#  'most',
#  'powerful',
#  'figures',
#  'regime',
#  'prominent',
#  'retained',
#  'influence',
#  'had',
#  'virtually',
#  'no',
#  'power',
#  'alexandros',
#  'yiotopoulos',
#  'is',
#  '58',
#  '59',
#  'years',
#  'old',
#  '213',
#  'people',
#  'were',
#  'killed',
#  '219',
#  'al-zarqawi',
#  'palestinian',
#  'jordanian',
#  'right-handed',
#  'left-handed',
#  'has',
#  'been',
#  'arrested',
#  'case',
#  'collin',
#  'finnerty',
#  'on',
#  'charges',
#  'sexual',
#  'offense',
#  'two',
#  'sophomore',
#  'duke',
#  'lacrosse',
#  'players',
#  'zarqawi',
#  'did',
#  'fact',
#  'survive',
#  'airstrike',
#  'abu',
#  'musab',
#  'an',
#  'ended',
#  'life',
#  'terrorist',
#  'leader',
#  'u.s.',
#  'air',
# ...

# %%
l=['apple','Banana','Mango']
for n in range(len(l)):
  if re.search('[A-Za-z0-9]',l[n]):
    l[n]=l[n].lower()

# %%
l
# Out:
# ['apple', 'banana', 'mango']
